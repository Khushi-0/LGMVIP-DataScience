# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushi-0/LGMVIP-DataScience/blob/main/Image_to_Pencil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![download.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# ## LetsGrowMore Internship January-2023 Batch
# **Author - Khushi Koladiya**

# %% [markdown]
# ## **Image to Pencil Sketch with Python**

# %% [markdown]
# ## **Import Libraries**
# OpenCV library is the only library needed for converting image to a pencil sketch with Python.
#
# We are also using matplotlib library for some visualizations.

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Read Photo**
# Below given command reads the file photo.jpg located in the current folder and stores in memory as img.

# %%
img=cv2.imread("/content/download1.jfif")

# %% [markdown]
# ## **Show Image using OpenCV**
# When the below given command is executed, the below photo will open.

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F2D17AF6160>

# %% [markdown]
# ## **Convert BGR to RGB**
# Using cvtColor method of OpenCV.

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.axis(False)
plt.show()

# %% [markdown]
# ## **Convert Image to a Pencil Sketch**
# Converting a photo to pencil sketch involves the following steps:

# %% [markdown]
# ### **Step 1: Convert to Grey Image**
# Using cvtColor function of OpenCV.

# %%
grey_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ### **Step 2: Invert Image**
# Inverting the image can be done by either of the following methods

# %%
invert_img=cv2.bitwise_not(grey_img)

# %% [markdown]
# ### **Step 3: Blur image**
# Apply Gaussian blur to the image. The second argument to the function is the kernel size, if should be a pair of odd numbers. Larger the kernel size, more blurred the image will be and it will lose its subtle features. For small images, kernel size of (3,3), (5,5) etc. will be sufficient, whereas for larger images, small kernel size do not create any impact. Appropriate kernel size can be selected by trial and error method.

# %%
blur_img=cv2.GaussianBlur(invert_img, (111,111),0)

# %% [markdown]
# ### **Step 4: Invert Blurred Image**
# Repeat step 2

# %%
invertblur_img=cv2.bitwise_not(blur_img)

# %% [markdown]
# ### **Step 5: Sketch**
# The sketch can be obtained by performing bit-wise division between the grayscale image and the inverted-blurred image.

# %%
sketch_img=cv2.divide(grey_img,invertblur_img, scale=256.0)

# %% [markdown]
# ### **Step 6: Save Sketch**

# %%
cv2.imwrite('sketch.png', sketch_img)
# Out:
# True

# %% [markdown]
# ### **Step 7: Display sketch**

# %%
cv2_imshow(sketch_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F2D17AF6190>

# %% [markdown]
# ## **Original Image vs Sketch**
# We can display the original image and sketch side by side for comparison.

# %%
plt.figure(figsize=(14,8))
plt.subplot(1,2,1)
plt.title('Original image', size=18)
plt.imshow(RGB_img)
plt.axis('off')
plt.subplot(1,2,2)
plt.title('Sketch', size=18)
rgb_sketch=cv2.cvtColor(sketch_img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_sketch)
plt.axis('off')
plt.show()
